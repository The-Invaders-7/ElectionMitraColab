# %%
# !pip install easyocr

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image

# %%
rcParams['figure.figsize'] = 16, 32

# %%
# !pip install pdf2image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !sudo apt-get install -y poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 174 kB of archives.
# After this operation, 754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 poppler-utils amd64 0.86.1-0ubuntu1.1 [174 kB]
# Fetched 174 kB in 1s (248 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package poppler-utils.
# ...

# %% [markdown]
# #Converting pdf to image

# %%
# !pip install pdf2image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# poppler-utils is already the newest version (0.86.1-0ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
from pdf2image import convert_from_path
 
# Store Pdf with convert_from_path function
images = convert_from_path('trial.pdf')
 
for i in range(len(images)):
   
      # Save pages as images in the pdf
    images[i].save('page'+ str(i) +'.jpeg', 'JPEG')

# %%
im  = img.open(r"page3.jpeg")

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1653x2339 at 0x7FC4104254E0>

# %% [markdown]
# Dimensions of the image

# %%
width, height = im.width, im.height
print(width, height)
# Out:
# 1653 2339

# %% [markdown]
# We need to crop this image now

# %%
left = 40
top = 220
right = width-60
bottom = height-150

im1 = im.crop((left, top, right, bottom))
im1
# Out:
# <PIL.Image.Image image mode=RGB size=1553x1969 at 0x7FC410393130>

# %% [markdown]
# Now try to access the section

# %%
width, height = im1.width, im1.height

# %%
left = 0
top = height/10
right = width/3
bottom = 2*height/10

imm = im1.crop((left, top, right, bottom))
imm = imm.convert("RGB")
imm
# Out:
# <PIL.Image.Image image mode=RGB size=518x197 at 0x7FC410393A00>

# %%
imm = imm.convert("RGB")
imm.save("imm.jpeg", "JPEG")

# %%
op = r1.readtext("imm.jpeg")

# %%
for i in op:
  print(i[1])
# Out:
# 108
# #11`^/3342961
# 208/41/110
# मतदाराचे
# पूर्णः जाघव संतोष मुरलीघर
# नांव
# शौऐ0
# वडिलांचे नाव
# जाधव
# मुरलीधर
# 4,ं"२ँ=
# घर क्रमांक
# वय : ५५
# लिंग : पु

# %%
left = 2*width/3
top = 9*height/10
right = width
bottom = height

imm = im1.crop((left, top, right, bottom))
imm = imm.convert("RGB")
imm
# Out:
# <PIL.Image.Image image mode=RGB size=518x197 at 0x7FC410424D00>

# %%
import easyocr

# %%
imm = imm.convert("RGB")
imm.save("imm.jpeg", "JPEG")

# %% [markdown]
# Creating two independent readers for hindi and english specifically since both together are not working fine

# %%
r1 = easyocr.Reader(['hi'])
r2 = easyocr.Reader(['en'])

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
op = r1.readtext("imm.jpeg")
opp = r2.readtext("imm.jpeg")

# %%
from googletrans import Translator
translator = Translator()

data = {}
j=0
for i in op:
  # if(j==1):
  #   data["_id"] = i[1]
  j+=1
  t = translator.translate(i[1]).text
  print(i[1], t)
print()

j=0
for i in opp:
  if(j==1):
    data["_id"] = i[1]
    
  j+=1
  print(i[1])
# Out:
# 134 134
# 7871970458 7871970458
# 208/41/146 208/41/146
# मतदाराचे पूर्णःकुलकर्णी निलिमा माधवराव Voter's Purna: Kulkarni Nilima Madhavrao
# नाव name
# पतीचे नाव Husband's Name
# माधवराव Madhavrao
# शंणभ0 cone
# ,1"ैँ= ,1"ैँ=
# घर क्रमांक house number
# वय : ७८ Age : 78
# लिंग gender
# स्री Ms
# कुलकर्णी Kulkarni
#
# 134
# TBZ1970458
# 208/41/146
# HdETTd quf. 3oouj ffashT HITRTA
# T
# 9d -4
# HIdRTT
# Photo
# Available
# TR 3Hi35
# 4 : 1C
# fozt
# 5
# gadff

# %%
op = reader.readtext("imm.jpeg")

# %% [markdown]
# #Hindi to English text conversion to insert data

# %%
translation = translator.translate("मतदाराचे पूर्ण नाव : कुलकर्णी निलिमा माधवराव").text

# %%
translation
# Out:
# 'Full Name of Voter : Kulkarni Nilima Madhavrao'

# %% [markdown]
# #Exttacting fields from the image

# %%
global imageString, firstName, middleName, lastName, age, gender, voterID

# %%
left = 0
top = height/10
right = width/3
bottom = 2*height/10

imm = im1.crop((left, top, right, bottom))
imm = imm.convert("RGB")
imm.save("imm.jpg", "JPEG")
imm
# Out:
# <PIL.Image.Image image mode=RGB size=518x197 at 0x7FC411AC1AB0>

# %% [markdown]
# ##Convert the image to a base64 string

# %%
import base64
with open("imm.jpg", "rb") as img_file:
    my_string = base64.b64encode(img_file.read())
imageString = my_string
print(my_string)
# Out:
# b'...'

# %%
width, height = imm.width, imm.height

# %%
left = 120
top = 45
right = 350
bottom = 80

f1 = imm.crop((left, top, right, bottom))
f1 = f1.convert("RGB")
f1.save("f1.jpg", "JPEG")
f1
# Out:
# <PIL.Image.Image image mode=RGB size=230x35 at 0x7FC4045D2DD0>

# %%
op = r1.readtext("f1.jpg")
st = ""
for i in op:
  st+=(i[1]+" ")
print(st)
data = translator.translate(st).text
lastName = data.split(" ")[0]
firstName = data.split(" ")[1]
middleName = data.split(" ")[2]
# Out:
# जाधव संतोष मुरलीधर

# %%
print(firstName, lastName, middleName)
# Out:
# Santosh Jadhav Muralidhar

# %%
imm
# Out:
# <PIL.Image.Image image mode=RGB size=518x197 at 0x7FC411AC1AB0>

# %%
block_path = os.path.join(CROPPED_IMG_PATH, f'{filename}.jpeg')

    block_img  = img.open(block_path)
    # width, height = block_img.width, block_img.height

    left = 0
    top = 0
    right = 500
    bottom = 40

    f1 = block_img.crop((left, top, right, bottom))
    f1 = f1.convert("RGB")
    temp_storage_path = os.path.join(TEMP_STORAGE_PATH, f'{filename}_voter_id.jpeg')
    f1.save(temp_storage_path, "JPEG")

    op = reader.readtext(temp_storage_path)
    st = ""
    for i in op:
      st+=(i[1]+" ")
    data = translator.translate(st).text
    voterID = data.split(" ")[1]
    return voterID

f2 = imm.crop((left, top, right, bottom))
f2 = f2.convert("RGB")
f2.save("f2.jpg", "JPEG")
f2
# Out:
# <PIL.Image.Image image mode=RGB size=500x40 at 0x7FC4045F24A0>

# %%
op = r2.readtext("f2.jpg")
st = ""
for i in op:
  st+=(i[1]+" ")
print(st)
data = translator.translate(st).text
voterID = data.split(" ")[1]
voterID
# Out:
# 108 HMW3342961 208/41/110
# 'HMW3342961'

# %%
left = 130
top = imm.height-40
right = 300
bottom = imm.height

f3 = imm.crop((left, top, right, bottom))
f3 = f3.convert("RGB")
f3.save("f3.jpg", "JPEG")
f3
# Out:
# <PIL.Image.Image image mode=RGB size=300x40 at 0x7FC4045F34C0>

# %%
op = r1.readtext("f3.jpg")
st = ""
# age = 
if(translator.translate(op[1][1].split(":")[1]).text == 'PU'):
  gender = "Male"
else:
  gender = "Female"
# Out:
# PU
# ु

# %%
gender
# Out:
# 'Male'

# %%
str(imageString)[2:-2]
# Out:
# "'"

# %% [markdown]
# #Connecting to Mongo DB

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 28.2 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %% [markdown]
# Establishing a connection

# %%
CONNECTION_STRING = "mongodb+srv://tanishq777:tanishq777@cluster0.lzgyb.mongodb.net/ElectionMitra?retryWrites=true&w=majority"
client = MongoClient(CONNECTION_STRING)

# %% [markdown]
# Querying the data

# %%
client["voters"]
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.lzgyb.mongodb.net:27017', 'cluster0-shard-00-00.lzgyb.mongodb.net:27017', 'cluster0-shard-00-01.lzgyb.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-y5mufa-shard-0', tls=True), 'voters')

# %%
c = client["ElectionMitra"]

# %%
voters = c["Voters"].find()

# %% [markdown]
# Inserting the data

# %%
addVoter = c["Voters"]
voter = {
   "firstName" : firstName,
   "middleName" : middleName,
   "lastName" : lastName,
   "gender": gender,
   "voterID" : voterID,
   "imageString": str(imageString)[2:-2],
   "district":"Pune",
   "city":"Pune",
   "ward":"Beed"
}
addVoter.insert_one(voter)

# %% [markdown]
# #All the requirements as per problem are satisfied

# %%
voters = c["voters"].find()

# %%
voters[0]
# Out:
# {'_id': ObjectId('64056ccbcec370138308f98f'),
#  "Voter's Name": 'Trial',
#  "Voter's ID": 1213,
#  "Voter's Age": 34,
#  "Voter's Sex": 'Male'}

# %% [markdown]
# Adding multiple voters

# %%
voter1 = {
   "Voter's Name":"Trial1",
   "Voter's ID": 12134,
   "Voter's Age": 94,
   "Voter's Sex": "Female"
}
voter2 = {
   "Voter's Name":"Trial2",
   "Voter's ID": 1294,
   "Voter's Age": 24,
   "Voter's Sex": "Male"
}
addVoter.insert_many([voter1, voter2])

# %%
voters = c["voters"].find()

# %% [markdown]
# Reading all the data from database

# %%
for i in voters:
  print(i)
# Out:
# {'_id': ObjectId('64056ccbcec370138308f98f'), "Voter's Name": 'Trial', "Voter's ID": 1213, "Voter's Age": 34, "Voter's Sex": 'Male'}
# {'_id': ObjectId('64056d1dcec370138308f990'), "Voter's Name": 'Trial1', "Voter's ID": 12134, "Voter's Age": 94, "Voter's Sex": 'Female'}
# {'_id': ObjectId('64056d1dcec370138308f991'), "Voter's Name": 'Trial2', "Voter's ID": 1294, "Voter's Age": 24, "Voter's Sex": 'Male'}

# %%
data = {}
j = 0
for i in op:
  if(j == 1):
    data["_id"] = i[1]
  print(i[1])
print()
j=0
for i in opp:
  if(j == 1):
    data["_id"] = i[1]
  print(i[1])
